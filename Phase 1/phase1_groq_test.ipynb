# %%
# !pip install groq -q

# %%
from groq import Groq

# %%
from google.colab import userdata
from groq import Groq

client = Groq(
    api_key=userdata.get('GROQ_API_KEY')
)

# %%
response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {
            "role": "user",
            "content": "Explain RAG in simple words"
        }
    ]
)
print(response.choices[0].message.content)
# Out:
# RAG (Retrieval-Augmented Generation) is a technology that helps computers understand and generate human-like text.
#
# Imagine you're having a conversation with a friend, and you want to tell them about a topic you're not very familiar with. You might look up some information online or in a book to learn more about it before explaining it to your friend.
#
# RAG works in a similar way. When you ask a computer a question or give it a topic to write about, it uses its "memory" (a large database of information) to find relevant information. Then, it uses that information to generate a response or write about the topic in a way that sounds natural and human-like.
#
# The key steps in RAG are:
#
# 1. **Retrieval**: The computer searches its database to find relevant information related to the topic.
# 2. **Augmentation**: The computer uses the retrieved information to "augment" or improve its understanding of the topic.
# 3. **Generation**: The computer generates a response or writes about the topic based on its augmented understanding.
#
# RAG helps computers provide more accurate and informative responses, making them sound more intelligent and human-like.
